# %% [markdown]
# # **LSTM On Recipes Data**

# %% [markdown]
# #Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import json
import re
import string

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, losses
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #Parameters

# %%
VOCAB_SIZE = 10000
MAX_LEN = 200
EMBEDDING_DIM = 100
N_UNITS = 128
VALIDATION_SPLIT = 0.2
SEED = 42
LOAD_MODEL = False
BATCH_SIZE = 32
EPOCHS = 25

# %% [markdown]
# # 1.Load the Data

# %%
# Load the full dataset
with open("/content/drive/MyDrive/full_format_recipes.json") as json_data:
    recipe_data = json.load(json_data)

# %%
# Filter the dataset
filtered_data = [
    "Recipe for " + x["title"] + " | " + " ".join(x["directions"])
    for x in recipe_data
    if "title" in x
    and x["title"] is not None
    and "directions" in x
    and x["directions"] is not None
]

# %%
# Count the recipes
n_recipes = len(filtered_data)
print(f"{n_recipes} recipes loaded")
# Out:
# 20111 recipes loaded

# %%
example = filtered_data[9]
print(example)
# Out:
# Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas  | Chop enough parsley leaves to measure 1 tablespoon; reserve. Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan, covered, 5 minutes. Meanwhile, sprinkle gelatin over water in a medium bowl and let soften 1 minute. Strain broth through a fine-mesh sieve into bowl with gelatin and stir to dissolve. Season with salt and pepper. Set bowl in an ice bath and cool to room temperature, stirring. Toss ham with reserved parsley and divide among jars. Pour gelatin on top and chill until set, at least 1 hour. Whisk together mayonnaise, mustard, vinegar, 1/4 teaspoon salt, and 1/4 teaspoon pepper in a large bowl. Stir in celery, cornichons, and potatoes. Pulse peas with marjoram, oil, 1/2 teaspoon pepper, and 1/4 teaspoon salt in a food processor to a coarse mash. Layer peas, then potato salad, over ham.

# %% [markdown]
# #2.Tokeinse the data

# %%
# Pad the punctuation, to treat them as separate 'words'
def pad_punctuation(s):
    s = re.sub(f"([{string.punctuation}])", r" \1 ", s)
    s = re.sub(" +", " ", s)
    return s


text_data = [pad_punctuation(x) for x in filtered_data]

# %%
# Display an example of a recipe
example_data = text_data[9]
example_data
# Out:
# 'Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas | Chop enough parsley leaves to measure 1 tablespoon ; reserve . Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan , covered , 5 minutes . Meanwhile , sprinkle gelatin over water in a medium bowl and let soften 1 minute . Strain broth through a fine - mesh sieve into bowl with gelatin and stir to dissolve . Season with salt and pepper . Set bowl in an ice bath and cool to room temperature , stirring . Toss ham with reserved parsley and divide among jars . Pour gelatin on top and chill until set , at least 1 hour . Whisk together mayonnaise , mustard , vinegar , 1 / 4 teaspoon salt , and 1 / 4 teaspoon pepper in a large bowl . Stir in celery , cornichons , and potatoes . Pulse peas with marjoram , oil , 1 / 2 teaspoon pepper , and 1 / 4 teaspoon salt in a food processor to a coarse mash . Layer peas , then potato salad , over ham . '

# %%
# Convert to a Tensorflow Dataset
text_ds = (
    tf.data.Dataset.from_tensor_slices(text_data)
    .batch(BATCH_SIZE)
    .shuffle(1000)
)

# %%
# Create a vectorisation layer
vectorize_layer = layers.TextVectorization(
    standardize="lower",
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=MAX_LEN + 1,
)

# %%
# Adapt the layer to the training set
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()

# %%
# Display some token:word mappings
for i, word in enumerate(vocab[:10]):
    print(f"{i}: {word}")
# Out:
# 0:
# 1: [UNK]
# 2: .
# 3: ,
# 4: and
# 5: to
# 6: in
# 7: the
# 8: with
# 9: a

# %%
# Display the same example converted to ints
example_tokenised = vectorize_layer(example_data)
print(example_tokenised.numpy())
# Out:
# [  26   16  557    1    8  298  335  189    4 1054  494   27  332  228
#   235  262    5  594   11  133   22  311    2  332   45  262    4  671
#     4   70    8  171    4   81    6    9   65   80    3  121    3   59
#    12    2  299    3   88  650   20   39    6    9   29   21    4   67
#   529   11  164    2  320  171  102    9  374   13  643  306   25   21
#     8  650    4   42    5  931    2   63    8   24    4   33    2  114
#    21    6  178  181 1245    4   60    5  140  112    3   48    2  117
#   557    8  285  235    4  200  292  980    2  107  650   28   72    4
#   108   10  114    3   57  204   11  172    2   73  110  482    3  298
#     3  190    3   11   23   32  142   24    3    4   11   23   32  142
#    33    6    9   30   21    2   42    6  353    3 3224    3    4  150
#     2  437  494    8 1281    3   37    3   11   23   15  142   33    3
#     4   11   23   32  142   24    6    9  291  188    5    9  412  572
#     2  230  494    3   46  335  189    3   20  557    2    0    0    0
#     0    0    0    0    0]

# %% [markdown]
# #3. Create Training Dataset

# %%
# Create the training set of recipes and the same text shifted by one word
def prepare_inputs(text):
    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]
    return x, y


train_ds = text_ds.map(prepare_inputs)

# %% [markdown]
# #4. Build the lSTM.

# %%
inputs = layers.Input(shape=(None,), dtype="int32")
x = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)(inputs)
x = layers.LSTM(N_UNITS, return_sequences=True)(x)
outputs = layers.Dense(VOCAB_SIZE, activation="softmax")(x)
lstm = models.Model(inputs, outputs)
lstm.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, None)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, None, 100)           │       1,000,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, None, 128)           │         117,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, None, 10000)         │       1,290,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,407,248 (9.18 MB)
#  Trainable params: 2,407,248 (9.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
if LOAD_MODEL:
    # model.load_weights('./models/model')
    lstm = models.load_model("./models/lstm", compile=False)

# %% [markdown]
# #5. Train the LSTM.

# %%
loss_fn = losses.SparseCategoricalCrossentropy()
lstm.compile("adam", loss_fn)

# %%
# Create a TextGenerator checkpoint
class TextGenerator(callbacks.Callback):
    def __init__(self, index_to_word, top_k=10):
        self.index_to_word = index_to_word
        self.word_to_index = {
            word: index for index, word in enumerate(index_to_word)
        }  # <1>

    def sample_from(self, probs, temperature):  # <2>
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [
            self.word_to_index.get(x, 1) for x in start_prompt.split()
        ]  # <3>
        sample_token = None
        info = []
        while len(start_tokens) < max_tokens and sample_token != 0:  # <4>
            x = np.array([start_tokens])
            y = self.model.predict(x, verbose=0)  # <5>
            sample_token, probs = self.sample_from(y[0][-1], temperature)  # <6>
            info.append({"prompt": start_prompt, "word_probs": probs})
            start_tokens.append(sample_token)  # <7>
            start_prompt = start_prompt + " " + self.index_to_word[sample_token]
        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("recipe for", max_tokens=100, temperature=1.0)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint/checkpoint.weights.h5", # Changed the file extension to .weights.h5
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")

# Tokenize starting prompt
text_generator = TextGenerator(vocab)

# %%
lstm.fit(
    train_ds,
    epochs=EPOCHS,
    callbacks=[model_checkpoint_callback, tensorboard_callback, text_generator],
)
# Out:
# Epoch 1/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 5.0526
# generated text:
# recipe for braised melt beef sprigs | beef with beat 5 often and in shallow nonstick first smash oil . let vegetables liqueurs in lemon cup nv . coconut melted brown , tablespoon nutmeg and toss to 1 10 occasionally until buttermilk of - heat , fragrant , / pan in a skillet . metal mash tomatoes 2 - increase pan in worry and moderate 10 minutes . in high plastic fat 1 done in 1 / 2 occasionally . toothpick - build grill at mixture to inch the fat for cut sprigs , fish for thick and boil .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 37s 52ms/step - loss: 5.0498
# Epoch 2/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.0772
# generated text:
# recipe for but american trifles cheesecake with apple tom cucumber | roll easily collins into center of dish on a cooked through or ends of different sharp not firm 3 . ) preheat roast to low water , until yaki pieces are just golden the . beans , 15 seconds longer the excess it with the of broth and cook except salad , trace , dill , until fish is no thickens , about 2 minutes . add sauce mixture , garlic , beating
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - loss: 3.0769
# Epoch 3/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.5378
# generated text:
# recipe for café chicken and cherry scones | preheat to 350°f . working in thin and drippings a grill . bring to a medium bowl and add the motor to taste and cook to the grinder . mix with prune 3 / 4 cups butter slice the sugar and garlic and the dark ground for medium - low heat , garlic , reduce skillet and heat . whisk raisins , green thyme and salt . spread dough in roasting .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - loss: 2.5377
# Epoch 4/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.2806
# generated text:
# recipe for hazelnut gratin | 5 and remove oven to 10 seconds . stir together all ingredients and add 1 tablespoon oil . amaretti should be serving , then trim sorbets to release excess liquid leaves . spread cheese as pliable slices on top to combine . place eggs and in small bowl , coat both through marinade over and roast until just amber set , about 8 minutes . cut sides down , cut into back into 12 - inch round . melt butter in heavy broiler . heat oil on an work sheets until veal path in coals
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - loss: 2.2805
# Epoch 5/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.1214
# generated text:
# recipe for calabrian - salt patty salad with chinese bacon and toasted tomatoes | mix together potato , grated garlic vinegar , rosemary , salt , and salt in processor . whisk cheese , , mustard , and reserved gingerroot in small bowl to blend ; season with cilantro . season gently with salt and pepper and 3 / 4 cup rolls . transfer to taste with butter . spoon eggs into a bowl , gently mound yolk and scoop dressing into bowls . www . cut potatoes ; cut between 2 individual plates and transfer chicken to plates .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - loss: 2.1214
# Epoch 6/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.0042
# generated text:
# recipe for berry and red parsley soup | sauerkraut sauce holding the pasta in single layer . 3 . in a skillet cook 1 on a large pot over a work surface for 1 hour . heat a large floured 4 - iron thermometer , carefully working over low heat and cook , turning over once or twice , until soft and just opaque in a golden brown . transfer apples to salt and cook 2 slices and moving toasts on top sheets , and repeat with a spatula juices to 275°f . add 1 / 2 cup hot water
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 2.0042
# Epoch 7/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.9209
# generated text:
# recipe for irish lentil tenderloin with spicy almonds | melt butter seeds in a heavy medium saucepan and drain , then thinly . mix sauce ingredients , if using . make 2 tablespoons ice turkey drizzle so ( s flame ) . tie endives are style dashi , about 1 minute . transfer to a large bowl and season with salt and pepper . heat oil in cleaned skillet over medium - high heat until glaze is just cooked through and lightly brown on grill , about 4 minutes . transfer fish to a cutting board and let stand ,
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.9208
# Epoch 8/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.8707
# generated text:
# recipe for orange , smoked turkey | position rack in center . bring to simmer sugar , then then shallots and leek with crabmeat , tomatoes , parsley , 15 1 / 2 - inch dice to dutch oven and mix in cream , tossing by 2 inches and stir - fry until golden , about 15 minutes . transfer to 9 - inch - diameter deep dish ( do not overprocess ) . chill 15 minutes . line pan with parchment proof metal cake pan . add remaining minced stems and 2 tablespoons lemon juice , coriander , and
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.8707
# Epoch 9/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.8175
# generated text:
# recipe for microwave cookies with pork and olives underneath sandwiches | heat 1 tablespoon oil in a small heavy pan over moderately high heat until hot but not smoking . cook onion in oven until crisp - golden brown , about 15 minutes ; carefully as pearl garlic , jalapeño , and bell pepper to taste , celery with garlic , half , and salt and curry powder to taste and sauté until golden , about 5 minutes . add beans , yogurt , stirring powder , and olives ; simmer until cauliflower is very tender , stirring occasionally ,
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 35s 55ms/step - loss: 1.8175
# Epoch 10/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.7806
# generated text:
# recipe for penne with saffron - peas , tomato , and cider | stir pecans , honey and cream . cook pasta until bottoms are very tender , brushing with chicken , using dry , salt , pepper , thyme , paprika , and allspice in a small bowl until whites holds soft peaks and set aside . transfer to a 2 " skillets in a standing chimney tub to escape . pat skin dry and remaining 2 tablespoons butter and season with salt and pepper . in a skillet bring blanch half of water and garlic in pot and
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.7806
# Epoch 11/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.7414
# generated text:
# recipe for cabbage and walnuts - crab potatoes | preheat oven to 450°f . place nuts on a rimmed baking sheet and turn until end to hold shape . make 3 / 3 cup in bread crumbs over medium heat until it just enough to sides . turn out onto floured surface and turn in a large bowl with floured hands , tasting at grill and do not let it at drippings ) ( some hot fat will be tough ) . spread corn butter into griddle ( preferably stick so bottom as it ) and roast marks to 365°f
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 35s 55ms/step - loss: 1.7414
# Epoch 12/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.7207
# generated text:
# recipe for coconut and pomegranate crepes | finely grind grate orange seeds , 2 teaspoons ginger , and stalks in 42 - inch glass or bowl . drain . halve . cut each bread into 1 / 4 - inch cubes . cover , spreading down , using an electric x 2 - cup bundt pan . let the speed at high speed until they ' s to hold the pan and dry , for 15 minutes . then chill at least 3 months and yoghurt until cold , at least 6 hours .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.7207
# Epoch 13/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.6986
# generated text:
# recipe for egg spice cake | lightly flour bowl directly or - mesh sieve to extract as much small tablespoons and hen apple through large bowls of water runs it stand . add 1 cup ice cubes and in a dry non - stick / 4 - inch baking pan with 2 tablespoons orange peel . pierce remaining zucchini in middle of oven and let dough rest 30 minutes . trim excess . trim excess flour . roll out each slice evenly into 4 equal strips and place it on bottom of pan . 6 . in a heavy saucepan
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.6986
# Epoch 14/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.6772
# generated text:
# recipe for baked apples ; basil spread | preheat oven to 350°f . pat leg very still well to spread 1 / 2 cup hot water in each shallow baking dish and blend . pour topping over outer bottom to work surface ; tie with fork if using fresh . ) place bread in small bowl and arrange remaining lemons , tossing over raisins , and ginger atop . sprinkle topping evenly over chicken . drizzle with 1 tablespoon dressing . combine malt nectar , vinegar and remaining 1 / 3 cup salt in heavy medium saucepan . bring to
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 35s 55ms/step - loss: 1.6772
# Epoch 15/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.6528
# generated text:
# recipe for baked succotash with herb onions , apple , and morels | preheat oven to 350°f . forty 1 / 2 teaspoon each end of each with1 / 3 cup parsley and in a food processor grind to dry food processor . slowly with mushroom oils in a food processor running , drop another 1 / 2 cup dressing onto baking sheets . spread half of herb mixture on each of serving batter . heat 1 / 4 cup oil in a 12 - inch stick pan pan over medium - high heat until shimmering and sauté onions mixture
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.6528
# Epoch 16/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.6377
# generated text:
# recipe for hearty garden chicken with peas and bean lime vinaigrette | 1 . 4 . heat for 1 / 2 pounds yeast in a large heavy knife to coat wings and transfer them to bowl . pour marinade into a bowl and top with half of lettuce and arrange , dividing evenly . layer eggplant in each muffin cups , drizzle with olive mustard .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 33s 52ms/step - loss: 1.6377
# Epoch 17/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.6203
# generated text:
# recipe for baked sweet potatoes with ginger | preheat oven to 325°f . butter bottom of baking sheet with 1 / 2 teaspoon oil and sprinkle with 1 teaspoon salt and 3 / 4 - inch by 4 - inch - long baking sheet . add vinegar , sour raisins and 1 / 4 cup sugar and vanilla until well blended . gradually whisk in milk mixture . transfer to 4 additions . whisk in buttermilk in small bowl ; drizzle to combine . spoon batter into egg mixture , cover , and refrigerate remaining at least 4 hours at
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.6203
# Epoch 18/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.6087
# generated text:
# recipe for lemon blueberry flan with blackberry sauce | peel pears and remove seeds . whisk together all of the sugar ingredients in a small bowl until smooth before frozen . ( simple syrup may be hot enough hot water ) , then stir until blended . combine gelatin and mango in a 1 1 / 4 - inch champagne fitted with a bowl or chill . halve raw stem and form into 6 slices . leave porcini in a rubber band . to unmold , drop in 1 / 2 cup ice water and gently stir in water .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 35s 55ms/step - loss: 1.6087
# Epoch 19/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5879
# generated text:
# recipe for spinach , watercress , and prosciutto salad | preheat oven to 450°f . place potatoes in large nonstick baking pan and brush on 1 sheet . place ribs on platter . grill shrimp for 15 minutes . broil salmon skewers until very soft and all juices are slightly charred , about 5 minutes longer for medium - rare . 3 . cool . ladle into bowls alongside . pita toasts . divide cheeses among 4 plates . top with remaining peanuts .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 33s 53ms/step - loss: 1.5880
# Epoch 20/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5748
# generated text:
# recipe for bourbon braised with lemon filling | in a small saucepan , combine the peppercorns and salt . simmer mixture , whisking constantly , for about 2 minutes , stirring regularly , shake the rice stalk for another 1 1 / 2 cup . add the egg and simmer for 5 minutes . 5 ( don ' t overstuff ) . break the praline into the crock and set aside . 2 . preheat the oven to 350°f . in a large heavy ovenproof skillet over medium heat , cook the egg until golden and lightly browned on a
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 43s 56ms/step - loss: 1.5748
# Epoch 21/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5640
# generated text:
# recipe for jellied old fashioned oatmeal | position rack in upper third of oven and preheat oven to 400° . maintain oven temperature . combine first 4 ingredients in heavy medium saucepan to blend . whisk over medium heat until mixture begins to turn peaks form , whisking constantly with yolks about 8 minutes . remove from heat and mix in remaining ingredients . mix in cream . divide berry mixture among eight 5 - ounce ramekins ( spicy brown sugar ) thick at medium - thick sides from top , pressing on top . place about 2 tablespoons butter
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.5641
# Epoch 22/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5572
# generated text:
# recipe for orecchiette with tomatoes , thyme , and herbs | bring turkey broth and water to a simmer in a heavy pot over medium heat , whisking occasionally . stir to combine with 3 thyme sprigs and 1 / 2 cup stock for at least 30 seconds . just again 1 minute before serving .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - loss: 1.5572
# Epoch 23/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5448
# generated text:
# recipe for frisée and apple purée | combine panini in center of small skillet and toss well . sprinkle bread with salt and pepper and drizzle with 1 tablespoon olive oil . top with dipping sauce . fold yogurt mixture over and serve .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 31s 49ms/step - loss: 1.5449
# Epoch 24/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5360
# generated text:
# recipe for feta tart with racks of chestnuts | preheat oven to 350°f . line large baking sheet with parchment paper . press dough into " slices to form 3 3 / 4 - inch - diameter cake triangles . in large bowl , roll between sheets of pastry mixture , spacing apart . bake squash 30 minutes . transfer to racks to cool . ( can be prepared 3 days ahead . cover and chill . ) coarsely grate enough butter into heavy white mixture to blend . simmer mixture and bean keeps in remaining 5 1 1 /
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 35s 55ms/step - loss: 1.5360
# Epoch 25/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5373
# generated text:
# recipe for blueberry ice cream | make toasts in blender or food processor purée in processor until very thick and smooth , about 2 minutes . whisk in chocolate puree , lemon juice , and cinnamon sticks . press cherries through sieve into a small bowl of ice and top to allow gelatin to let stand 5 minutes , then discard leaves ; remove potatoes from bowl . chill juice , uncovered , 30 seconds . ( syrup can be made 1 week ahead . keep chilled . syrup keeps ganache and a month can set in a larger punch
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.5373

# %%
# Create the directory if it doesn't exist
# !mkdir -p ./models

# Save the final model
lstm.save("./models/lstm.keras")

# %% [markdown]
# #6. Generate Text using lstm

# %%
def print_probs(info, vocab, top_k=5):
    for i in info:
        print(f"\nPROMPT: {i['prompt']}")
        word_probs = i["word_probs"]
        p_sorted = np.sort(word_probs)[::-1][:top_k]
        i_sorted = np.argsort(word_probs)[::-1][:top_k]
        for p, i in zip(p_sorted, i_sorted):
            print(f"{vocab[i]}:   \t{np.round(100*p,2)}%")
        print("--------\n")

# %%
info = text_generator.generate(
    "recipe for roasted vegetables | chop 1 /", max_tokens=10, temperature=0.5
)
# Out:
# generated text:
# recipe for roasted vegetables | chop 1 / 2 cup

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for roasted vegetables | chop 1 /
# 2:   	58.72%
# 4:   	40.57%
# 3:   	0.65%
# 8:   	0.05%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2
# cup:   	50.33%
# cups:   	23.78%
# teaspoon:   	11.21%
# tablespoon:   	2.72%
# tsp:   	2.63%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=7, temperature=0.8
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | mix
#
#
# PROMPT: recipe for chocolate ice cream |
# in:   	23.64%
# combine:   	12.65%
# whisk:   	9.89%
# heat:   	6.65%
# beat:   	5.17%
# --------
